# %%
import pandas as pd
import requests
from datetime import datetime, timedelta
from bs4 import BeautifulSoup as bs
from my_passwords import my_password,API_key_flights
import my_functions as fn

# %%
# search by free text Berlin
url = "https://aerodatabox.p.rapidapi.com/airports/search/term"

querystring = {"q":"berlin","limit":"10","withFlightInfoOnly":"true"}

headers = {
	"X-RapidAPI-Key": API_key_flights,
	"X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
flight_json1=response.json()
print(flight_json1)
# Out:
# {'searchBy': 'berlin', 'count': 1, 'items': [{'icao': 'EDDB', 'iata': 'BER', 'name': 'Berlin Brandenburg', 'shortName': 'Brandenburg', 'municipalityName': 'Berlin', 'location': {'lat': 52.35139, 'lon': 13.493889}, 'countryCode': 'DE'}]}

# %%
pd.json_normalize(flight_json1["items"])
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 0  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
#
#    location.lat  location.lon
# 0      52.35139     13.493889

# %%
# search by location Berlin
url = "https://aerodatabox.p.rapidapi.com/airports/search/location"

querystring = {"lat":"52.31","lon":"13.24","radiusKm":"50","limit":"10","withFlightInfoOnly":"True"}

headers = {
	"X-RapidAPI-Key": API_key_flights,
	"X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

flight_json2=response.json()
print(flight_json2)
# Out:
# {'searchBy': {'lat': 52.31, 'lon': 13.24}, 'count': 1, 'items': [{'icao': 'EDDB', 'iata': 'BER', 'name': 'Berlin Brandenburg', 'shortName': 'Brandenburg', 'municipalityName': 'Berlin', 'location': {'lat': 52.35139, 'lon': 13.493889}, 'countryCode': 'DE'}]}

# %%
pd.json_normalize(flight_json2["items"])
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 0  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
#
#    location.lat  location.lon
# 0      52.35139     13.493889

# %%
# search by free text Munich
url = "https://aerodatabox.p.rapidapi.com/airports/search/term"

querystring = {"q":"Munich","limit":"10","withFlightInfoOnly":"true"}

headers = {
	"X-RapidAPI-Key": API_key_flights,
	"X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
flight_json3=response.json()
print(flight_json3)
# Out:
# {'searchBy': 'Munich', 'count': 1, 'items': [{'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich ', 'shortName': 'Munich', 'municipalityName': 'Munich', 'location': {'lat': 48.3538, 'lon': 11.7861}, 'countryCode': 'DE'}]}

# %%
pd.json_normalize(flight_json3["items"])
# Out:
#    icao iata     name shortName municipalityName countryCode  location.lat  \
# 0  EDDM  MUC  Munich     Munich           Munich          DE       48.3538
#
#    location.lon
# 0       11.7861

# %%
# search by location Munich
url = "https://aerodatabox.p.rapidapi.com/airports/search/location"

querystring = {"lat":"48.08","lon":"11.34","radiusKm":"50","limit":"10","withFlightInfoOnly":"True"}



headers = {
	"X-RapidAPI-Key": API_key_flights,
	"X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

flight_json4=response.json()
print(flight_json4)
# Out:
# {'searchBy': {'lat': 48.08, 'lon': 11.34}, 'count': 1, 'items': [{'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich ', 'shortName': 'Munich', 'municipalityName': 'Munich', 'location': {'lat': 48.3538, 'lon': 11.7861}, 'countryCode': 'DE'}]}

# %%
pd.json_normalize(flight_json4["items"])
# Out:
#    icao iata     name shortName municipalityName countryCode  location.lat  \
# 0  EDDM  MUC  Munich     Munich           Munich          DE       48.3538
#
#    location.lon
# 0       11.7861

# %% [markdown]
# Connect to SQL

# %%
schema = "gans"
host = "127.0.0.1"
user = "root"
password = my_password
port = 3306

connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %%
cities_from_sql_df = pd.read_sql("cities", con=connection_string)
cities_from_sql_df
# Out:
#    city_id       city country_code
# 0        1     Berlin           DE
# 1        2    Hamburg           DE
# 2        3     Munich           DE
# 3        4  Stuttgart           DE

# %% [markdown]
# Airports

# %%
# This function takes the cities dataframe and returns the Dataframe that contains all airports data
def get_airpots_info(cities_df):
  
  # Initialising the airport dictionary
  airport_dic = {"city_id": [],
    "airport_icao": [],
    "airport_name": []
    }
  
  for city_name in cities_df["city"]: # For each city in the cities Dataframe
    
    # Define the sections that will together form the url 
    # These sections were generated by the API
    url = "https://aerodatabox.p.rapidapi.com/airports/search/term" # URL of the airport API
    querystring = {"q":city_name,"limit":"10","withFlightInfoOnly":"True"} # We need the city name and only airports with flights
    headers = {
      "X-RapidAPI-Key": API_key_flights, # Change the generated API key to our API Key
      "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
    }

    airport = requests.get(url, headers=headers, params=querystring) # Send the request
    airport_json=airport.json() # Get the response in a JSON format
    
    # We take the city_id and the country code from the cities dataframe
    city_id = cities_df.loc[cities_df["city"] == city_name, "city_id"].values[0]
    country_code = cities_df.loc[cities_df["city"] == city_name, "country_code"].values[0]
    for w in airport_json["items"]: # For each airport in the JSON response
      if(w["countryCode"]==country_code): # Since we are searching for airport by the airport name and not by coordinates,  
                                          # we need to check if the country code is the same as the one of the city
                                          # The same city name can exist in more than one country
        # Adding all the information about the airport to the airport dictionary
        airport_dic["city_id"].append(city_id)
        airport_dic["airport_icao"].append(w["icao"])
        airport_dic["airport_name"].append(w["name"])
    
    # Create the weather Dataframe
    airport_df = pd.DataFrame(airport_dic)

  return airport_df

# %%
airport_infos_df=get_airpots_info(cities_from_sql_df)
airport_infos_df
# Out:
#    city_id airport_icao        airport_name
# 0        1         EDDB  Berlin Brandenburg
# 1        2         EDDH            Hamburg
# 2        3         EDDM             Munich
# 3        4         EDDS          Stuttgart

# %%
# Send airports data to the table "airports" and "cities_airports"
airport_infos_df.loc[:,["airport_icao","airport_name"]].to_sql('airports',
                if_exists='append',
                con=connection_string,
                index=False)

airport_infos_df.loc[:,["city_id","airport_icao"]].to_sql('cities_airports',
                if_exists='append',
                con=connection_string,
                index=False)
# Out:
# 4

# %%
airport_infos_from_sql = pd.read_sql("airports", con=connection_string) # Read the table "airports"
print(airport_infos_from_sql)
cities_airports_from_sql = pd.read_sql("cities_airports", con=connection_string) # Read the table "cities_airports"
print(cities_airports_from_sql)
# Out:
#   airport_icao        airport_name
# 0         EDDB  Berlin Brandenburg
# 1         EDDH            Hamburg
# 2         EDDM             Munich
# 3         EDDS          Stuttgart
#    city_id airport_icao
# 0        1         EDDB
# 1        2         EDDH
# 2        3         EDDM
# 3        4         EDDS

# %% [markdown]
# Flights

# %%
today=datetime.now()
tomorrow= (today + timedelta(1)).strftime("%Y-%m-%d")
from_date1=tomorrow+"T"+"00:00"

to_date2=tomorrow+"T"+"11:59"
print(from_date1,to_date2)
from_date3=tomorrow+"T"+"12:00"
to_date4=tomorrow+"T"+"23:59"
print(from_date3,to_date4)
# Out:
# 2024-03-19T00:00 2024-03-19T11:59
# 2024-03-19T12:00 2024-03-19T23:59

# %%
icao_list=airport_infos_df["airport_icao"]
icao_list
# Out:
# 0    EDDB
# 1    EDDH
# 2    EDDM
# 3    EDDS
# Name: airport_icao, dtype: object

# %%
import json
import requests

url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/EDDB/{from_date1}/{to_date2}"

querystring = {"direction":"Arrival","withCancelled":"true"}

headers = {
    "X-RapidAPI-Key": API_key_flights,
    "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
pd.json_normalize(response.json()["arrivals"])
# Out:
# {'arrivals': [{'movement': {'airport': {'icao': 'OTHH', 'iata': 'DOH', 'name': 'Doha'}, 'scheduledTime': {'utc': '2024-03-19 05:50Z', 'local': '2024-03-19 06:50+01:00'}, 'revisedTime': {'utc': '2024-03-19 05:50Z', 'local': '2024-03-19 06:50+01:00'}, 'terminal': '1', 'gate': 'X07', 'baggageBelt': 'A4', 'quality': ['Basic', 'Live']}, 'number': 'QR 79', 'status': 'Expected', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'model': 'Boeing 787-9'}, 'airline': {'name': 'Qatar Airways', 'iata': 'QR', 'icao': 'QTR'}}, {'movement': {'airport': {'icao': 'EVRA', 'iata': 'RIX', 'name': 'Riga'}, 'scheduledTime': {'utc': '2024-03-19 06:35Z', 'local': '2024-03-19 07:35+01:00'}, 'revisedTime': {'utc': '2024-03-19 06:35Z', 'local': '2024-03-19 07:35+01:00'}, 'terminal': '2', 'gate': 'Z34', 'baggageBelt': 'C1', 'quality': ['Basic', 'Live']}, 'number': 'FR 2600', 'status': 'Expected', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'model': 'Boeing 737-800 (winglets)'}, 'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}}, {'movement': {'airport': {'icao': 'LFSB', 'iata': 'BSL', 'name': 'Bâle/Mulhouse'}, 'scheduledTime': {'utc': '2024-03-19 06:45Z', 'local': '2024-03-19 07:45+01:00'}, 'revisedTime': {'utc': '2024-03-19 06:45Z', 'local': '2024-03-19 07:45+01:00'}, 'terminal': '1', 'gate': 'A36', 'baggageBelt': 'A3', 'quality': ['Basic', 'Live']}, 'number': 'DS 1185', 'status': 'Expected', 'codeshareStatus': 'IsCodeshared', 'isCargo': False, 'aircraft': {'reg': 'HB-JXR', 'modeS': '4B1A2B', 'model': 'Airbus A320'}, 'airline': {'name': 'Easyjet Switzerland', 'iata': 'DS', 'icao': 'EZS'}}, {'movement': {'airport': {'icao': 'LFSB', 'iata': 'BSL', 'name': 'Bâle/Mulhouse'}, 'scheduledTime': {'utc': '2024-03-19 06:45Z', 'local': '2024-03-19 07:45+01:00'}, 'revisedTime': {'utc': '2024-03-19 06:45Z', 'local': '2024-03-19 07:45+01:00'}, 'terminal': '1', 'gate': 'A36', 'baggageBelt': 'A3', 'quality': ['Basic', 'Live']}, 'number': 'U2 1185', 'status': 'Expected', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'HB-JXR', 'modeS': '4B1A2B', 'model': 'Airbus A320'}, 'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}}, {'movement': {'airport': {'icao': 'LHBP', 'iata': 'BUD', 'name': 'Budapest'}, 'scheduledTime': {'utc': '2024-03-19 06:45Z', 'local': '2024-03-19 07:45+01:00'}, 'revisedTime': {'utc': '2024-03-19 06:45Z', 'local': '2024-03-19 07:45+01:00'}, 'terminal': '2', 'gate': 'Z36', 'baggageBelt': 'C1', 'quality': ['Basic', 'Live']}, 'number': 'W6 2315', 'status': 'Expected', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'model': 'Airbus A321-100'}, 'airline': {'name': 'Wizz Air', 'iata': 'W6', 'icao': 'WZZ'}}, {'movement': {'airport': {'icao': 'UGKO', 'iata': 'KUT', 'name': 'Kutaisi'}, 'scheduledTime': {'utc': '2024-03-19 06:50Z', 'local': '2024-03-19 07:50+01:00'}, 'revisedTime': {'utc': '2024-03-19 06:50Z', 'local': '2024-03-19 07:50+01:00'}, 'terminal': '2', 'gate': 'Z42', 'baggageBelt': 'C3', 'quality': ['Basic', 'Live']}, 'number': 'W6 6407', 'status': 'Expected', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'model': 'Airbus A321-100'}, 'airline': {'name': 'Wizz Air', 'iata': 'W6', 'icao': 'WZZ'}}, {'movement': {'airport': {'icao': 'EVRA', 'iata': 'RIX', 'name': 'Riga'}, 'scheduledTime': {'utc': '2024-03-19 06:55Z', 'local': '2024-03-19 07:55+01:00'}, 'revisedTime': {'utc': '2024-03-19 06:55Z', 'local': '2024-03-19 07:55+01:00'}, 'terminal': '1', 'gate': 'A31', 'baggageBelt': 'A3', 'quality': ['Basic', 'Live']}, 'number': 'A3 3219', 'status': 'Expected', 'codeshareStatus': 'IsCodeshared', 'isCargo': False, 'aircraft': {'model': 'Airbus A220-300'}, 'airline': {'name': 'Aegean', 'iata': 'A3', 'icao': 'AEE'}}, {'movement': {'airport': {'icao': 'EVRA', 'iata': 'RIX', 'name': 'Riga'}, 'scheduledTime': {'utc': '2024-03-19 06:55Z', 'local': '2024-03-19 07:55+01:00'}, 'revisedTime': {'utc': '2024-03-19 06:55Z', 'local': '2024-03-19 07:55+01:00'}, 'termin ...
#      number    status codeshareStatus  isCargo movement.airport.icao  \
# 0     QR 79  Expected      IsOperator    False                  OTHH
# 1   FR 2600  Expected      IsOperator    False                  EVRA
# 2   DS 1185  Expected    IsCodeshared    False                  LFSB
# 3   U2 1185  Expected      IsOperator    False                  LFSB
# 4   W6 2315  Expected      IsOperator    False                  LHBP
# ..      ...       ...             ...      ...                   ...
# 71  AF 1734  Expected      IsOperator    False                  LFPG
# 72  EC 5148  Expected    IsCodeshared    False                  LFPG
# 73  U2 5148  Expected      IsOperator    False                  LFPG
# 74   FR 133  Expected      IsOperator    False                  LEBL
# 75   LH 180  Expected      IsOperator    False                  EDDF
#
#    movement.airport.iata movement.airport.name movement.scheduledTime.utc  \
# 0                    DOH                  Doha          2024-03-19 05:50Z
# 1                    RIX                  Riga          2024-03-19 06:35Z
# 2                    BSL         Bâle/Mulhouse          2024-03-19 06:45Z
# 3                    BSL         Bâle/Mulhouse          2024-03-19 06:45Z
# 4                    BUD              Budapest          2024-03-19 06:45Z
# ..                   ...                   ...                        ...
# 71                   CDG                 Paris          2024-03-19 10:30Z
# 72                   CDG                 Paris          2024-03-19 10:35Z
# 73                   CDG                 Paris          2024-03-19 10:35Z
# 74                   BCN             Barcelona          2024-03-19 10:55Z
# 75                   FRA     Frankfurt-am-Main          2024-03-19 10:55Z
#
#    movement.scheduledTime.local movement.revisedTime.utc  ... movement.gate  \
# 0        2024-03-19 06:50+01:00        2024-03-19 05:50Z  ...           X07
# 1        2024-03-19 07:35+01:00        2024-03-19 06:35Z  ...           Z34
# 2        2024-03-19 07:45+01:00        2024-03-19 06:45Z  ...           A36
# 3        2024-03-19 07:45+01:00        2024-03-19 06:45Z  ...           A36
# 4        2024-03-19 07:45+01:00        2024-03-19 06:45Z  ...           Z36
# ..                          ...                      ...  ...           ...
# 71       2024-03-19 11:30+01:00        2024-03-19 10:30Z  ...           B07
# 72       2024-03-19 11:35+01:00        2024-03-19 10:35Z  ...           A32
# 73       2024-03-19 11:35+01:00        2024-03-19 10:35Z  ...           A32
# 74       2024-03-19 11:55+01:00        2024-03-19 10:55Z  ...           Z34
# 75       2024-03-19 11:55+01:00        2024-03-19 10:55Z  ...           B17
#
#    movement.baggageBelt movement.quality               aircraft.model  \
# 0                    A4    [Basic, Live]                 Boeing 787-9
# 1                    C1    [Basic, Live]    Boeing 737-800 (winglets)
# 2                    A3    [Basic, Live]                  Airbus A320
# 3                    A3    [Basic, Live]                  Airbus A320
# 4                    C1    [Basic, Live]              Airbus A321-100
# ..                  ...              ...                          ...
# 71                   B1    [Basic, Live]         Embraer Lineage 1000
# 72                   A3    [Basic, Live]              Airbus A320-200
# 73                   A3    [Basic, Live]              Airbus A320-200
# 74                   C1    [Basic, Live]    Boeing 737-800 (winglets)
# 75                   B3    [Basic, Live]  Airbus A320-200 (sharklets)
#
#            airline.name airline.iata airline.icao aircraft.reg aircraft.modeS  \
# 0         Qatar Airways           QR          QTR          NaN            NaN
# 1               Ryanair           FR          RYR          NaN            NaN
# 2   Easyjet Switzerland           DS          EZS       HB-JXR         4B1A2B
# 3               easyJet           U2          EZY       HB-JXR         4B1A2B
# 4              Wizz Air           W6          WZZ          NaN            NaN
# ..                  ...          ...          ...          ...            ...
# 71           Air France           AF          AFR          NaN            NaN
# 72       EasyJet Europe           EC          EJU          NaN            NaN
# 73              easyJet           U2          EZY          NaN            NaN
# 74              Ryanair           FR          RYR          NaN            NaN
# 75            Lufthansa           LH          DLH       D-AIUO         3C66AF
#
#    callSign
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 71      NaN
# 72      NaN
# 73      NaN
# 74      NaN
# 75      NaN
#
# [76 rows x 22 columns]

# %%
url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/EDDB/{from_date1}/{to_date2}"

querystring = {"withLeg":"true",
               "direction":"Arrival",
               "withCancelled":"false",
               "withCodeshared":"true",
               "withCargo":"false",
               "withPrivate":"false"}

headers = {
    "X-RapidAPI-Key": API_key_flights,
    "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
pd.json_normalize(response.json()["arrivals"])
# Out:
# {'arrivals': [{'departure': {'airport': {'icao': 'OTHH', 'iata': 'DOH', 'name': 'Doha'}, 'scheduledTime': {'utc': '2024-03-18 23:35Z', 'local': '2024-03-19 02:35+03:00'}, 'quality': ['Basic']}, 'arrival': {'scheduledTime': {'utc': '2024-03-19 05:50Z', 'local': '2024-03-19 06:50+01:00'}, 'revisedTime': {'utc': '2024-03-19 05:50Z', 'local': '2024-03-19 06:50+01:00'}, 'terminal': '1', 'gate': 'X07', 'baggageBelt': 'A4', 'quality': ['Basic', 'Live']}, 'number': 'QR 79', 'status': 'Expected', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'model': 'Boeing 787-9'}, 'airline': {'name': 'Qatar Airways', 'iata': 'QR', 'icao': 'QTR'}}, {'departure': {'airport': {'icao': 'EVRA', 'iata': 'RIX', 'name': 'Riga'}, 'scheduledTime': {'utc': '2024-03-19 04:45Z', 'local': '2024-03-19 06:45+02:00'}, 'quality': ['Basic']}, 'arrival': {'scheduledTime': {'utc': '2024-03-19 06:35Z', 'local': '2024-03-19 07:35+01:00'}, 'revisedTime': {'utc': '2024-03-19 06:35Z', 'local': '2024-03-19 07:35+01:00'}, 'terminal': '2', 'gate': 'Z34', 'baggageBelt': 'C1', 'quality': ['Basic', 'Live']}, 'number': 'FR 2600', 'status': 'Expected', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'model': 'Boeing 737-800 (winglets)'}, 'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}}, {'departure': {'airport': {'icao': 'LFSB', 'iata': 'BSL', 'name': 'Bâle/Mulhouse'}, 'scheduledTime': {'utc': '2024-03-19 05:15Z', 'local': '2024-03-19 06:15+01:00'}, 'revisedTime': {'utc': '2024-03-19 05:15Z', 'local': '2024-03-19 06:15+01:00'}, 'gate': '86', 'quality': ['Basic', 'Live']}, 'arrival': {'scheduledTime': {'utc': '2024-03-19 06:45Z', 'local': '2024-03-19 07:45+01:00'}, 'revisedTime': {'utc': '2024-03-19 06:45Z', 'local': '2024-03-19 07:45+01:00'}, 'terminal': '1', 'gate': 'A36', 'baggageBelt': 'A3', 'quality': ['Basic', 'Live']}, 'number': 'DS 1185', 'status': 'Expected', 'codeshareStatus': 'IsCodeshared', 'isCargo': False, 'aircraft': {'reg': 'HB-JXR', 'modeS': '4B1A2B', 'model': 'Airbus A320'}, 'airline': {'name': 'Easyjet Switzerland', 'iata': 'DS', 'icao': 'EZS'}}, {'departure': {'airport': {'icao': 'LFSB', 'iata': 'BSL', 'name': 'Bâle/Mulhouse'}, 'scheduledTime': {'utc': '2024-03-19 05:15Z', 'local': '2024-03-19 06:15+01:00'}, 'revisedTime': {'utc': '2024-03-19 05:15Z', 'local': '2024-03-19 06:15+01:00'}, 'gate': '86', 'quality': ['Basic', 'Live']}, 'arrival': {'scheduledTime': {'utc': '2024-03-19 06:45Z', 'local': '2024-03-19 07:45+01:00'}, 'revisedTime': {'utc': '2024-03-19 06:45Z', 'local': '2024-03-19 07:45+01:00'}, 'terminal': '1', 'gate': 'A36', 'baggageBelt': 'A3', 'quality': ['Basic', 'Live']}, 'number': 'U2 1185', 'status': 'Expected', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'HB-JXR', 'modeS': '4B1A2B', 'model': 'Airbus A320'}, 'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}}, {'departure': {'airport': {'icao': 'LHBP', 'iata': 'BUD', 'name': 'Budapest'}, 'scheduledTime': {'utc': '2024-03-19 05:10Z', 'local': '2024-03-19 06:10+01:00'}, 'terminal': '2B', 'quality': ['Basic']}, 'arrival': {'scheduledTime': {'utc': '2024-03-19 06:45Z', 'local': '2024-03-19 07:45+01:00'}, 'revisedTime': {'utc': '2024-03-19 06:45Z', 'local': '2024-03-19 07:45+01:00'}, 'terminal': '2', 'gate': 'Z36', 'baggageBelt': 'C1', 'quality': ['Basic', 'Live']}, 'number': 'W6 2315', 'status': 'Expected', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'model': 'Airbus A321-100'}, 'airline': {'name': 'Wizz Air', 'iata': 'W6', 'icao': 'WZZ'}}, {'departure': {'airport': {'icao': 'UGKO', 'iata': 'KUT', 'name': 'Kutaisi'}, 'scheduledTime': {'utc': '2024-03-19 02:40Z', 'local': '2024-03-19 06:40+04:00'}, 'quality': ['Basic']}, 'arrival': {'scheduledTime': {'utc': '2024-03-19 06:50Z', 'local': '2024-03-19 07:50+01:00'}, 'revisedTime': {'utc': '2024-03-19 06:50Z', 'local': '2024-03-19 07:50+01:00'}, 'terminal': '2', 'gate': 'Z42', 'baggageBelt': 'C3', 'quality': ['Basic', 'Live']}, 'number': 'W6 6407', 'status':  ...
#      number    status codeshareStatus  isCargo departure.airport.icao  \
# 0     QR 79  Expected      IsOperator    False                   OTHH
# 1   FR 2600  Expected      IsOperator    False                   EVRA
# 2   DS 1185  Expected    IsCodeshared    False                   LFSB
# 3   U2 1185  Expected      IsOperator    False                   LFSB
# 4   W6 2315  Expected      IsOperator    False                   LHBP
# ..      ...       ...             ...      ...                    ...
# 71  AF 1734  Expected      IsOperator    False                   LFPG
# 72  EC 5148  Expected    IsCodeshared    False                   LFPG
# 73  U2 5148  Expected      IsOperator    False                   LFPG
# 74   FR 133  Expected      IsOperator    False                   LEBL
# 75   LH 180  Expected      IsOperator    False                   EDDF
#
#    departure.airport.iata departure.airport.name departure.scheduledTime.utc  \
# 0                     DOH                   Doha           2024-03-18 23:35Z
# 1                     RIX                   Riga           2024-03-19 04:45Z
# 2                     BSL          Bâle/Mulhouse           2024-03-19 05:15Z
# 3                     BSL          Bâle/Mulhouse           2024-03-19 05:15Z
# 4                     BUD               Budapest           2024-03-19 05:10Z
# ..                    ...                    ...                         ...
# 71                    CDG                  Paris           2024-03-19 08:45Z
# 72                    CDG                  Paris                         NaN
# 73                    CDG                  Paris           2024-03-19 08:45Z
# 74                    BCN              Barcelona           2024-03-19 08:15Z
# 75                    FRA      Frankfurt-am-Main           2024-03-19 09:45Z
#
#    departure.scheduledTime.local departure.quality  ... airline.iata  \
# 0         2024-03-19 02:35+03:00           [Basic]  ...           QR
# 1         2024-03-19 06:45+02:00           [Basic]  ...           FR
# 2         2024-03-19 06:15+01:00     [Basic, Live]  ...           DS
# 3         2024-03-19 06:15+01:00     [Basic, Live]  ...           U2
# 4         2024-03-19 06:10+01:00           [Basic]  ...           W6
# ..                           ...               ...  ...          ...
# 71        2024-03-19 09:45+01:00           [Basic]  ...           AF
# 72                           NaN                []  ...           EC
# 73        2024-03-19 09:45+01:00           [Basic]  ...           U2
# 74        2024-03-19 09:15+01:00     [Basic, Live]  ...           FR
# 75        2024-03-19 10:45+01:00     [Basic, Live]  ...           LH
#
#    airline.icao departure.revisedTime.utc departure.revisedTime.local  \
# 0           QTR                       NaN                         NaN
# 1           RYR                       NaN                         NaN
# 2           EZS         2024-03-19 05:15Z      2024-03-19 06:15+01:00
# 3           EZY         2024-03-19 05:15Z      2024-03-19 06:15+01:00
# 4           WZZ                       NaN                         NaN
# ..          ...                       ...                         ...
# 71          AFR                       NaN                         NaN
# 72          EJU                       NaN                         NaN
# 73          EZY                       NaN                         NaN
# 74          RYR         2024-03-19 08:15Z      2024-03-19 09:15+01:00
# 75          DLH         2024-03-19 09:45Z      2024-03-19 10:45+01:00
#
#    departure.gate aircraft.reg aircraft.modeS departure.terminal  \
# 0             NaN          NaN            NaN                NaN
# 1             NaN          NaN            NaN                NaN
# 2              86       HB-JXR         4B1A2B                NaN
# 3              86       HB-JXR         4B1A2B                NaN
# 4             NaN          NaN            NaN                 2B
# ..            ...          ...            ...                ...
# 71            NaN          NaN            NaN                 2G
# 72            NaN          NaN            NaN                NaN
# 73            NaN          NaN            NaN                 2B
# 74            NaN          NaN            NaN                  2
# 75              A       D-AIUO         3C66AF                  1
#
#    departure.checkInDesk callSign
# 0                    NaN      NaN
# 1                    NaN      NaN
# 2                    NaN      NaN
# 3                    NaN      NaN
# 4                    NaN      NaN
# ..                   ...      ...
# 71                   NaN      NaN
# 72                   NaN      NaN
# 73                   NaN      NaN
# 74                   NaN      NaN
# 75               259-488      NaN
#
# [76 rows x 30 columns]

# %%
from pytz import timezone
from datetime import datetime,timedelta
icao = "EDDB" # Searching for flights for Berlin Brandenburg airport
berlin_timezone = timezone('Europe/Berlin')
today=datetime.now(berlin_timezone).date()
tomorrow= (today + timedelta(1))
times = [["00:00","11:59"],["12:00","23:59"]]
# The AeroDataBox API only returns flight data for 12 hours. 
# To get data for a whole day, we used two requests in a for loop. 
for time in times:
    url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{tomorrow}T{time[0]}/{tomorrow}T{time[1]}"

    querystring = {"withLeg":"true",
                "direction":"Arrival",
                "withCancelled":"false",
                "withCodeshared":"true",
                "withCargo":"false",
                "withPrivate":"false"}

    headers = {
        'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
        'x-rapidapi-key': "14a44098c8mshe4536a007985112p1e3b4bjsn8fd805eb6bd4" #api_key
        }

    response = requests.request("GET",
                                url,
                                headers = headers,
                                params = querystring)

    flights_json = response.json()

# %%
flights_json
# Out:
# {'arrivals': [{'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'scheduledTime': {'utc': '2024-03-19 10:00Z',
#      'local': '2024-03-19 11:00+01:00'},
#     'revisedTime': {'utc': '2024-03-19 10:00Z',
#      'local': '2024-03-19 11:00+01:00'},
#     'terminal': 'erminal2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 11:00Z',
#      'local': '2024-03-19 12:00+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:00Z',
#      'local': '2024-03-19 12:00+01:00'},
#     'terminal': '2',
#     'gate': 'Z30',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'D8 3302',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737 MAX 8 '},
#    'airline': {'name': 'Norwegian Air Sweden', 'iata': 'D8', 'icao': 'NSZ'}},
#   {'departure': {'airport': {'icao': 'BIKF',
#      'iata': 'KEF',
#      'name': 'Reykjavik'},
#     'scheduledTime': {'utc': '2024-03-19 07:30Z',
#      'local': '2024-03-19 07:30+00:00'},
#     'revisedTime': {'utc': '2024-03-19 07:30Z',
#      'local': '2024-03-19 07:30+00:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 11:00Z',
#      'local': '2024-03-19 12:00+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:00Z',
#      'local': '2024-03-19 12:00+01:00'},
#     'terminal': '1',
#     'gate': 'A10',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FI 528',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737 MAX 8 '},
#    'airline': {'name': 'Icelandair', 'iata': 'FI', 'icao': 'ICE'}},
#   {'departure': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-19 09:50Z',
#      'local': '2024-03-19 10:50+01:00'},
#     'revisedTime': {'utc': '2024-03-19 09:50Z',
#      'local': '2024-03-19 10:50+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 11:00Z',
#      'local': '2024-03-19 12:00+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:00Z',
#      'local': '2024-03-19 12:00+01:00'},
#     'terminal': '1',
#     'gate': 'B10',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 2206',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LIML', 'iata': 'LIN', 'name': 'Milan'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 11:10Z',
#      'local': '2024-03-19 12:10+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:10Z',
#      'local': '2024-03-19 12:10+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5064',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'GCTS',
#      'iata': 'TFS',
#      'name': 'Tenerife Island'},
#     'scheduledTime': {'utc': '2024-03-19 06:00Z',
#      'local': '2024-03-19 06:00+00:00'},
#     'revisedTime': {'utc': '2024-03-19 06:00Z',
#      'local': '2024-03-19 06:00+00:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 11:10Z',
#      'local': '2024-03-19 12:10+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:10Z',
#      'local': '2024-03-19 12:10+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 2419',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LIMC', 'iata': 'MXP', 'name': 'Milan'},
#     'scheduledTime': {'utc': '2024-03-19 09:20Z',
#      'local': '2024-03-19 10:20+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 11:10Z',
#      'local': '2024-03-19 12:10+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:10Z',
#      'local': '2024-03-19 12:10+01:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 9',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LIML', 'iata': 'LIN', 'name': 'Milan'},
#     'scheduledTime': {'utc': '2024-03-19 09:30Z',
#      'local': '2024-03-19 10:30+01:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 11:10Z',
#      'local': '2024-03-19 12:10+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:10Z',
#      'local': '2024-03-19 12:10+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5064',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EGSS', 'iata': 'STN', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-19 09:30Z',
#      'local': '2024-03-19 09:30+00:00'},
#     'revisedTime': {'utc': '2024-03-19 09:30Z',
#      'local': '2024-03-19 09:30+00:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 11:15Z',
#      'local': '2024-03-19 12:15+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:15Z',
#      'local': '2024-03-19 12:15+01:00'},
#     'terminal': '2',
#     'gate': 'Z40',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 145',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LICJ', 'iata': 'PMO', 'name': 'Palermo'},
#     'scheduledTime': {'utc': '2024-03-19 08:40Z',
#      'local': '2024-03-19 09:40+01:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 11:15Z',
#      'local': '2024-03-19 12:15+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:15Z',
#      'local': '2024-03-19 12:15+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 3361',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737 MAX 8 '},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EFHK',
#      'iata': 'HEL',
#      'name': 'Helsinki'},
#     'scheduledTime': {'utc': '2024-03-19 09:20Z',
#      'local': '2024-03-19 11:20+02:00'},
#     'revisedTime': {'utc': '2024-03-19 09:20Z',
#      'local': '2024-03-19 11:20+02:00'},
#     'terminal': '2',
#     'checkInDesk': '211',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 11:20Z',
#      'local': '2024-03-19 12:20+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:20Z',
#      'local': '2024-03-19 12:20+01:00'},
#     'terminal': '1',
#     'gate': 'A02',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 1433',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#   {'departure': {'airport': {'icao': 'EGLC', 'iata': 'LCY', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-19 09:40Z',
#      'local': '2024-03-19 09:40+00:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 11:20Z',
#      'local': '2024-03-19 12:20+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:20Z',
#      'local': '2024-03-19 12:20+01:00'},
#     'terminal': '1',
#     'gate': 'X06',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 7027',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 11:30Z',
#      'local': '2024-03-19 12:30+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:30Z',
#      'local': '2024-03-19 12:30+01:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 227',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#   {'departure': {'airport': {'icao': 'LTAI', 'iata': 'AYT', 'name': 'Antalya'},
#     'scheduledTime': {'utc': '2024-03-19 07:55Z',
#      'local': '2024-03-19 10:55+03:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 11:35Z',
#      'local': '2024-03-19 12:35+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:35Z',
#      'local': '2024-03-19 12:35+01:00'},
#     'terminal': '1',
#     'gate': 'X03',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'XQ 160',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737 MAX 8 '},
#    'airline': {'name': 'Sun Express', 'iata': 'XQ', 'icao': 'SXS'}},
#   {'departure': {'airport': {'icao': 'LTFJ',
#      'iata': 'SAW',
#      'name': 'Istanbul'},
#     'scheduledTime': {'utc': '2024-03-19 08:40Z',
#      'local': '2024-03-19 11:40+03:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 11:40Z',
#      'local': '2024-03-19 12:40+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:40Z',
#      'local': '2024-03-19 12:40+01:00'},
#     'terminal': '1',
#     'gate': 'Y03',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'TK 7728',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321-100'},
#    'airline': {'name': 'Turkish Airlines', 'iata': 'TK', 'icao': 'THY'}},
#   {'departure': {'airport': {'icao': 'ENGM', 'iata': 'OSL', 'name': 'Oslo'},
#     'scheduledTime': {'utc': '2024-03-19 10:20Z',
#      'local': '2024-03-19 11:20+01:00'},
#     'revisedTime': {'utc': '2024-03-19 10:20Z',
#      'local': '2024-03-19 11:20+01:00'},
#     'checkInDesk': '123',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 11:55Z',
#      'local': '2024-03-19 12:55+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:55Z',
#      'local': '2024-03-19 12:55+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'DY 1104',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Norwegian Air Shuttle', 'iata': 'DY', 'icao': 'NOZ'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-19 10:45Z',
#      'local': '2024-03-19 11:45+01:00'},
#     'revisedTime': {'utc': '2024-03-19 10:45Z',
#      'local': '2024-03-19 11:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-488',
#     'gate': 'A',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 11:55Z',
#      'local': '2024-03-19 12:55+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:55Z',
#      'local': '2024-03-19 12:55+01:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 182',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIQS', 'modeS': '3C6633', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LEMD', 'iata': 'MAD', 'name': 'Madrid'},
#     'scheduledTime': {'utc': '2024-03-19 08:55Z',
#      'local': '2024-03-19 09:55+01:00'},
#     'revisedTime': {'utc': '2024-03-19 08:55Z',
#      'local': '2024-03-19 09:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 12:00Z',
#      'local': '2024-03-19 13:00+01:00'},
#     'revisedTime': {'utc': '2024-03-19 12:00Z',
#      'local': '2024-03-19 13:00+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'P6 2023',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321-100'},
#    'airline': {'name': 'Privilege Style', 'iata': 'P6', 'icao': 'PVG'}},
#   {'departure': {'airport': {'icao': 'LTBJ', 'iata': 'ADB', 'name': 'İzmir'},
#     'scheduledTime': {'utc': '2024-03-19 08:50Z',
#      'local': '2024-03-19 11:50+03:00'},
#     'revisedTime': {'utc': '2024-03-19 08:50Z',
#      'local': '2024-03-19 11:50+03:00'},
#     'terminal': 'I',
#     'checkInDesk': '54',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 12:05Z',
#      'local': '2024-03-19 13:05+01:00'},
#     'revisedTime': {'utc': '2024-03-19 12:05Z',
#      'local': '2024-03-19 13:05+01:00'},
#     'terminal': '1',
#     'gate': 'X17',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'XQ 946',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737 MAX 8 '},
#    'airline': {'name': 'Sun Express', 'iata': 'XQ', 'icao': 'SXS'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'scheduledTime': {'utc': '2024-03-19 11:10Z',
#      'local': '2024-03-19 12:10+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:10Z',
#      'local': '2024-03-19 12:10+01:00'},
#     'terminal': 'erminal3',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 12:10Z',
#      'local': '2024-03-19 13:10+01:00'},
#     'revisedTime': {'utc': '2024-03-19 12:10Z',
#      'local': '2024-03-19 13:10+01:00'},
#     'terminal': '1',
#     'gate': 'B17',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'SK 1673',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'SAS', 'iata': 'SK', 'icao': 'SAS'}},
#   {'departure': {'airport': {'icao': 'EGLL', 'iata': 'LHR', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-19 10:30Z',
#      'local': '2024-03-19 10:30+00:00'},
#     'revisedTime': {'utc': '2024-03-19 10:30Z',
#      'local': '2024-03-19 10:30+00:00'},
#     'terminal': '5',
#     'checkInDesk': 'D',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 12:25Z',
#      'local': '2024-03-19 13:25+01:00'},
#     'revisedTime': {'utc': '2024-03-19 12:25Z',
#      'local': '2024-03-19 13:25+01:00'},
#     'terminal': '1',
#     'gate': 'Y06',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 982',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'OTHH', 'iata': 'DOH', 'name': 'Doha'},
#     'scheduledTime': {'utc': '2024-03-19 06:10Z',
#      'local': '2024-03-19 09:10+03:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 12:25Z',
#      'local': '2024-03-19 13:25+01:00'},
#     'revisedTime': {'utc': '2024-03-19 12:25Z',
#      'local': '2024-03-19 13:25+01:00'},
#     'terminal': '1',
#     'gate': 'X07',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'QR 81',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787-9'},
#    'airline': {'name': 'Qatar Airways', 'iata': 'QR', 'icao': 'QTR'}},
#   {'departure': {'airport': {'icao': 'LTFM',
#      'iata': 'IST',
#      'name': 'Istanbul'},
#     'scheduledTime': {'utc': '2024-03-19 09:35Z',
#      'local': '2024-03-19 12:35+03:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 12:25Z',
#      'local': '2024-03-19 13:25+01:00'},
#     'revisedTime': {'utc': '2024-03-19 12:25Z',
#      'local': '2024-03-19 13:25+01:00'},
#     'terminal': '1',
#     'gate': 'X01',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'TK 1725',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321-100'},
#    'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam'},
#     'scheduledTime': {'utc': '2024-03-19 11:30Z',
#      'local': '2024-03-19 12:30+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:30Z',
#      'local': '2024-03-19 12:30+01:00'},
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 12:45Z',
#      'local': '2024-03-19 13:45+01:00'},
#     'revisedTime': {'utc': '2024-03-19 12:45Z',
#      'local': '2024-03-19 13:45+01:00'},
#     'terminal': '1',
#     'gate': 'B02',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1825',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BGC',
#     'modeS': '48455A',
#     'model': 'Boeing 737-700 (winglets)'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#   {'departure': {'airport': {'icao': 'BKPR',
#      'iata': 'PRN',
#      'name': 'Prishtina'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 12:55Z',
#      'local': '2024-03-19 13:55+01:00'},
#     'revisedTime': {'utc': '2024-03-19 12:55Z',
#      'local': '2024-03-19 13:55+01:00'},
#     'terminal': '1',
#     'gate': 'X06',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5366',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-19 11:45Z',
#      'local': '2024-03-19 12:45+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:45Z',
#      'local': '2024-03-19 12:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-488',
#     'gate': 'A',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 12:55Z',
#      'local': '2024-03-19 13:55+01:00'},
#     'revisedTime': {'utc': '2024-03-19 12:55Z',
#      'local': '2024-03-19 13:55+01:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 184',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AILD', 'modeS': '3C6584', 'model': 'Airbus A319'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'HECA', 'iata': 'CAI', 'name': 'Cairo'},
#     'scheduledTime': {'utc': '2024-03-19 08:35Z',
#      'local': '2024-03-19 10:35+02:00'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 12:55Z',
#      'local': '2024-03-19 13:55+01:00'},
#     'revisedTime': {'utc': '2024-03-19 12:55Z',
#      'local': '2024-03-19 13:55+01:00'},
#     'terminal': '1',
#     'gate': 'X03',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'MS 731',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'EgyptAir', 'iata': 'MS', 'icao': 'MSR'}},
#   {'departure': {'airport': {'icao': 'BKPR',
#      'iata': 'PRN',
#      'name': 'Prishtina'},
#     'scheduledTime': {'utc': '2024-03-19 10:30Z',
#      'local': '2024-03-19 11:30+01:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 12:55Z',
#      'local': '2024-03-19 13:55+01:00'},
#     'revisedTime': {'utc': '2024-03-19 12:55Z',
#      'local': '2024-03-19 13:55+01:00'},
#     'terminal': '1',
#     'gate': 'X06',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5366',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca'},
#     'scheduledTime': {'utc': '2024-03-19 10:10Z',
#      'local': '2024-03-19 11:10+01:00'},
#     'revisedTime': {'utc': '2024-03-19 10:10Z',
#      'local': '2024-03-19 11:10+01:00'},
#     'terminal': 'N',
#     'checkInDesk': '080-085',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 13:00Z',
#      'local': '2024-03-19 14:00+01:00'},
#     'revisedTime': {'utc': '2024-03-19 13:00Z',
#      'local': '2024-03-19 14:00+01:00'},
#     'terminal': '1',
#     'gate': 'A35',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5120',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca'},
#     'scheduledTime': {'utc': '2024-03-19 10:10Z',
#      'local': '2024-03-19 11:10+01:00'},
#     'revisedTime': {'utc': '2024-03-19 10:10Z',
#      'local': '2024-03-19 11:10+01:00'},
#     'terminal': 'N',
#     'checkInDesk': '080-085',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 13:00Z',
#      'local': '2024-03-19 14:00+01:00'},
#     'revisedTime': {'utc': '2024-03-19 13:00Z',
#      'local': '2024-03-19 14:00+01:00'},
#     'terminal': '1',
#     'gate': 'A35',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5120',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'scheduledTime': {'utc': '2024-03-19 11:40Z',
#      'local': '2024-03-19 12:40+01:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 13:05Z',
#      'local': '2024-03-19 14:05+01:00'},
#     'revisedTime': {'utc': '2024-03-19 13:05Z',
#      'local': '2024-03-19 14:05+01:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 966',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#   {'departure': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna'},
#     'scheduledTime': {'utc': '2024-03-19 12:10Z',
#      'local': '2024-03-19 13:10+01:00'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 13:25Z',
#      'local': '2024-03-19 14:25+01:00'},
#     'revisedTime': {'utc': '2024-03-19 13:25Z',
#      'local': '2024-03-19 14:25+01:00'},
#     'terminal': '1',
#     'gate': 'B17',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 229',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#   {'departure': {'airport': {'icao': 'LTFJ',
#      'iata': 'SAW',
#      'name': 'Istanbul'},
#     'scheduledTime': {'utc': '2024-03-19 10:30Z',
#      'local': '2024-03-19 13:30+03:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 13:35Z',
#      'local': '2024-03-19 14:35+01:00'},
#     'revisedTime': {'utc': '2024-03-19 13:35Z',
#      'local': '2024-03-19 14:35+01:00'},
#     'terminal': '1',
#     'gate': 'X17',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'PC 979',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Pegasus', 'iata': 'PC', 'icao': 'PGT'}},
#   {'departure': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'scheduledTime': {'utc': '2024-03-19 12:05Z',
#      'local': '2024-03-19 13:05+01:00'},
#     'terminal': '2F',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 13:50Z',
#      'local': '2024-03-19 14:50+01:00'},
#     'revisedTime': {'utc': '2024-03-19 13:50Z',
#      'local': '2024-03-19 14:50+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 1234',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A220-300'},
#    'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#   {'departure': {'airport': {'icao': 'LIRN', 'iata': 'NAP', 'name': 'Nápoli'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 13:50Z',
#      'local': '2024-03-19 14:50+01:00'},
#     'revisedTime': {'utc': '2024-03-19 13:50Z',
#      'local': '2024-03-19 14:50+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5052',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LIRN', 'iata': 'NAP', 'name': 'Nápoli'},
#     'scheduledTime': {'utc': '2024-03-19 11:30Z',
#      'local': '2024-03-19 12:30+01:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 13:50Z',
#      'local': '2024-03-19 14:50+01:00'},
#     'revisedTime': {'utc': '2024-03-19 13:50Z',
#      'local': '2024-03-19 14:50+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5052',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-19 12:45Z',
#      'local': '2024-03-19 13:45+01:00'},
#     'revisedTime': {'utc': '2024-03-19 12:45Z',
#      'local': '2024-03-19 13:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-488',
#     'gate': 'A',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 13:55Z',
#      'local': '2024-03-19 14:55+01:00'},
#     'revisedTime': {'utc': '2024-03-19 13:55Z',
#      'local': '2024-03-19 14:55+01:00'},
#     'terminal': '1',
#     'gate': 'B10',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 186',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIZI', 'modeS': '3C6749', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-19 12:45Z',
#      'local': '2024-03-19 13:45+01:00'},
#     'revisedTime': {'utc': '2024-03-19 12:45Z',
#      'local': '2024-03-19 13:45+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 13:55Z',
#      'local': '2024-03-19 14:55+01:00'},
#     'revisedTime': {'utc': '2024-03-19 13:55Z',
#      'local': '2024-03-19 14:55+01:00'},
#     'terminal': '1',
#     'gate': 'B03',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1940',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#     'scheduledTime': {'utc': '2024-03-19 12:50Z',
#      'local': '2024-03-19 13:50+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 14:00Z',
#      'local': '2024-03-19 15:00+01:00'},
#     'revisedTime': {'utc': '2024-03-19 14:00Z',
#      'local': '2024-03-19 15:00+01:00'},
#     'terminal': '1',
#     'gate': 'B02',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 4',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart'},
#     'scheduledTime': {'utc': '2024-03-19 13:05Z',
#      'local': '2024-03-19 14:05+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 14:20Z',
#      'local': '2024-03-19 15:20+01:00'},
#     'revisedTime': {'utc': '2024-03-19 14:20Z',
#      'local': '2024-03-19 15:20+01:00'},
#     'terminal': '1',
#     'gate': 'A20',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 2004',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'scheduledTime': {'utc': '2024-03-19 13:10Z',
#      'local': '2024-03-19 14:10+01:00'},
#     'revisedTime': {'utc': '2024-03-19 13:10Z',
#      'local': '2024-03-19 14:10+01:00'},
#     'terminal': 'B',
#     'checkInDesk': '161,170',
#     'gate': 'A25',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 14:20Z',
#      'local': '2024-03-19 15:20+01:00'},
#     'revisedTime': {'utc': '2024-03-19 14:20Z',
#      'local': '2024-03-19 15:20+01:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 9042',
#    'callSign': 'GWI4ZU',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LEBL',
#      'iata': 'BCN',
#      'name': 'Barcelona'},
#     'scheduledTime': {'utc': '2024-03-19 11:40Z',
#      'local': '2024-03-19 12:40+01:00'},
#     'revisedTime': {'utc': '2024-03-19 11:40Z',
#      'local': '2024-03-19 12:40+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 14:20Z',
#      'local': '2024-03-19 15:20+01:00'},
#     'revisedTime': {'utc': '2024-03-19 14:20Z',
#      'local': '2024-03-19 15:20+01:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 149',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EIDW', 'iata': 'DUB', 'name': 'Dublin'},
#     'scheduledTime': {'utc': '2024-03-19 12:05Z',
#      'local': '2024-03-19 12:05+00:00'},
#     'revisedTime': {'utc': '2024-03-19 12:05Z',
#      'local': '2024-03-19 12:05+00:00'},
#     'terminal': '1',
#     'checkInDesk': '1204-1319',
#     'gate': '103',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 14:20Z',
#      'local': '2024-03-19 15:20+01:00'},
#     'revisedTime': {'utc': '2024-03-19 14:20Z',
#      'local': '2024-03-19 15:20+01:00'},
#     'terminal': '2',
#     'gate': 'Z44',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 3669',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 14:20Z',
#      'local': '2024-03-19 15:20+01:00'},
#     'revisedTime': {'utc': '2024-03-19 14:20Z',
#      'local': '2024-03-19 15:20+01:00'},
#     'terminal': '1',
#     'gate': 'A20',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 5387',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A319'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EGLL', 'iata': 'LHR', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-19 12:40Z',
#      'local': '2024-03-19 12:40+00:00'},
#     'revisedTime': {'utc': '2024-03-19 12:40Z',
#      'local': '2024-03-19 12:40+00:00'},
#     'terminal': '5',
#     'checkInDesk': 'D',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 14:35Z',
#      'local': '2024-03-19 15:35+01:00'},
#     'revisedTime': {'utc': '2024-03-19 14:35Z',
#      'local': '2024-03-19 15:35+01:00'},
#     'terminal': '1',
#     'gate': 'X06',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 984',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'EBBR',
#      'iata': 'BRU',
#      'name': 'Brussels'},
#     'scheduledTime': {'utc': '2024-03-19 13:10Z',
#      'local': '2024-03-19 14:10+01:00'},
#     'revisedTime': {'utc': '2024-03-19 13:10Z',
#      'local': '2024-03-19 14:10+01:00'},
#     'checkInDesk': '08',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 14:35Z',
#      'local': '2024-03-19 15:35+01:00'},
#     'revisedTime': {'utc': '2024-03-19 14:35Z',
#      'local': '2024-03-19 15:35+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 163',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800 (winglets)'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LWSK', 'iata': 'SKP', 'name': 'Skopje'},
#     'scheduledTime': {'utc': '2024-03-19 12:20Z',
#      'local': '2024-03-19 13:20+01:00'},
#     'revisedTime': {'utc': '2024-03-19 12:20Z',
#      'local': '2024-03-19 13:20+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 14:35Z',
#      'local': '2024-03-19 15:35+01:00'},
#     'revisedTime': {'utc': '2024-03-19 14:35Z',
#      'local': '2024-03-19 15:35+01:00'},
#     'terminal': '2',
#     'gate': 'Z42',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'W6 7739',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321-100'},
#    'airline': {'name': 'Wizz Air', 'iata': 'W6', 'icao': 'WZZ'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam'},
#     'scheduledTime': {'utc': '2024-03-19 13:20Z',
#      'local': '2024-03-19 14:20+01:00'},
#     'revisedTime': {'utc': '2024-03-19 13:20Z',
#      'local': '2024-03-19 14:20+01:00'},
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 14:40Z',
#      'local': '2024-03-19 15:40+01:00'},
#     'revisedTime': {'utc': '2024-03-19 14:40Z',
#      'local': '2024-03-19 15:40+01:00'},
#     'terminal': '1',
#     'gate': 'A02',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1829',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'E 195-E2'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#   {'departure': {'airport': {'icao': 'EGLC', 'iata': 'LCY', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-19 13:15Z',
#      'local': '2024-03-19 13:15+00:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 14:55Z',
#      'local': '2024-03-19 15:55+01:00'},
#     'revisedTime': {'utc': '2024-03-19 14:55Z',
#      'local': '2024-03-19 15:55+01:00'},
#     'terminal': '1',
#     'gate': 'X01',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 8493',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-19 13:45Z',
#      'local': '2024-03-19 14:45+01:00'},
#     'revisedTime': {'utc': '2024-03-19 13:45Z',
#      'local': '2024-03-19 14:45+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 14:55Z',
#      'local': '2024-03-19 15:55+01:00'},
#     'revisedTime': {'utc': '2024-03-19 14:55Z',
#      'local': '2024-03-19 15:55+01:00'},
#     'terminal': '1',
#     'gate': 'B17',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1942',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LTAI', 'iata': 'AYT', 'name': 'Antalya'},
#     'scheduledTime': {'utc': '2024-03-19 11:15Z',
#      'local': '2024-03-19 14:15+03:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 14:55Z',
#      'local': '2024-03-19 15:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'XQ 660',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737'},
#    'airline': {'name': 'Sun Express', 'iata': 'XQ', 'icao': 'SXS'}},
#   {'departure': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca'},
#     'scheduledTime': {'utc': '2024-03-19 12:30Z',
#      'local': '2024-03-19 13:30+01:00'},
#     'revisedTime': {'utc': '2024-03-19 12:30Z',
#      'local': '2024-03-19 13:30+01:00'},
#     'terminal': 'N',
#     'checkInDesk': '040-050',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 15:15Z',
#      'local': '2024-03-19 16:15+01:00'},
#     'revisedTime': {'utc': '2024-03-19 15:15Z',
#      'local': '2024-03-19 16:15+01:00'},
#     'terminal': '1',
#     'gate': 'A35',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8595',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna'},
#     'scheduledTime': {'utc': '2024-03-19 14:05Z',
#      'local': '2024-03-19 15:05+01:00'},
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 15:20Z',
#      'local': '2024-03-19 16:20+01:00'},
#     'revisedTime': {'utc': '2024-03-19 15:20Z',
#      'local': '2024-03-19 16:20+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 231',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#   {'departure': {'airport': {'icao': 'LPPT', 'iata': 'LIS', 'name': 'Lisbon'},
#     'scheduledTime': {'utc': '2024-03-19 11:40Z',
#      'local': '2024-03-19 11:40+00:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 15:20Z',
#      'local': '2024-03-19 16:20+01:00'},
#     'revisedTime': {'utc': '2024-03-19 15:20Z',
#      'local': '2024-03-19 16:20+01:00'},
#     'terminal': '1',
#     'gate': 'A07',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'TP 534',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'TAP Air Portugal', 'iata': 'TP', 'icao': 'TAP'}},
#   {'departure': {'airport': {'icao': 'EGLL', 'iata': 'LHR', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-19 13:50Z',
#      'local': '2024-03-19 13:50+00:00'},
#     'revisedTime': {'utc': '2024-03-19 13:50Z',
#      'local': '2024-03-19 13:50+00:00'},
#     'terminal': '5',
#     'checkInDesk': 'D',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 15:45Z',
#      'local': '2024-03-19 16:45+01:00'},
#     'revisedTime': {'utc': '2024-03-19 15:45Z',
#      'local': '2024-03-19 16:45+01:00'},
#     'terminal': '1',
#     'gate': 'Y02',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 994',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-19 14:45Z',
#      'local': '2024-03-19 15:45+01:00'},
#     'revisedTime': {'utc': '2024-03-19 14:45Z',
#      'local': '2024-03-19 15:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-488',
#     'gate': 'A',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 15:55Z',
#      'local': '2024-03-19 16:55+01:00'},
#     'revisedTime': {'utc': '2024-03-19 15:55Z',
#      'local': '2024-03-19 16:55+01:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 190',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AISF',
#     'modeS': '3C6666',
#     'model': 'Airbus A321-100'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#     'scheduledTime': {'utc': '2024-03-19 14:55Z',
#      'local': '2024-03-19 15:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 16:05Z',
#      'local': '2024-03-19 17:05+01:00'},
#     'revisedTime': {'utc': '2024-03-19 16:05Z',
#      'local': '2024-03-19 17:05+01:00'},
#     'terminal': '1',
#     'gate': 'B03',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 50',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart'},
#     'scheduledTime': {'utc': '2024-03-19 14:55Z',
#      'local': '2024-03-19 15:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 16:10Z',
#      'local': '2024-03-19 17:10+01:00'},
#     'revisedTime': {'utc': '2024-03-19 16:10Z',
#      'local': '2024-03-19 17:10+01:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8005',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321-100'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'scheduledTime': {'utc': '2024-03-19 15:00Z',
#      'local': '2024-03-19 16:00+01:00'},
#     'revisedTime': {'utc': '2024-03-19 15:00Z',
#      'local': '2024-03-19 16:00+01:00'},
#     'terminal': 'B',
#     'checkInDesk': '161,170',
#     'gate': 'A25',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 16:10Z',
#      'local': '2024-03-19 17:10+01:00'},
#     'revisedTime': {'utc': '2024-03-19 16:10Z',
#      'local': '2024-03-19 17:10+01:00'},
#     'terminal': '1',
#     'gate': 'A36',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8047',
#    'callSign': 'EWG27LR',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321-100'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 16:10Z',
#      'local': '2024-03-19 17:10+01:00'},
#     'revisedTime': {'utc': '2024-03-19 16:10Z',
#      'local': '2024-03-19 17:10+01:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 5397',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321-100'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EGPH',
#      'iata': 'EDI',
#      'name': 'Edinburgh'},
#     'scheduledTime': {'utc': '2024-03-19 14:00Z',
#      'local': '2024-03-19 14:00+00:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 16:10Z',
#      'local': '2024-03-19 17:10+01:00'},
#     'revisedTime': {'utc': '2024-03-19 16:10Z',
#      'local': '2024-03-19 17:10+01:00'},
#     'terminal': '1',
#     'gate': 'X17',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 3261',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'scheduledTime': {'utc': '2024-03-19 14:45Z',
#      'local': '2024-03-19 15:45+01:00'},
#     'terminal': '2F',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 16:25Z',
#      'local': '2024-03-19 17:25+01:00'},
#     'revisedTime': {'utc': '2024-03-19 16:25Z',
#      'local': '2024-03-19 17:25+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 1834',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#   {'departure': {'airport': {'icao': 'LIML', 'iata': 'LIN', 'name': 'Milan'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 16:30Z',
#      'local': '2024-03-19 17:30+01:00'},
#     'revisedTime': {'utc': '2024-03-19 16:30Z',
#      'local': '2024-03-19 17:30+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5066',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
# ...
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5102',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-19 20:15Z',
#      'local': '2024-03-19 21:15+01:00'},
#     'revisedTime': {'utc': '2024-03-19 20:15Z',
#      'local': '2024-03-19 21:15+01:00'},
#     'terminal': '1',
#     'checkInDesk': '259-488',
#     'gate': 'A',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 21:25Z',
#      'local': '2024-03-19 22:25+01:00'},
#     'revisedTime': {'utc': '2024-03-19 21:25Z',
#      'local': '2024-03-19 22:25+01:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 202',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AISG',
#     'modeS': '3C6667',
#     'model': 'Airbus A321-100'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LEBL',
#      'iata': 'BCN',
#      'name': 'Barcelona'},
#     'scheduledTime': {'utc': '2024-03-19 18:40Z',
#      'local': '2024-03-19 19:40+01:00'},
#     'revisedTime': {'utc': '2024-03-19 18:40Z',
#      'local': '2024-03-19 19:40+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 21:30Z',
#      'local': '2024-03-19 22:30+01:00'},
#     'revisedTime': {'utc': '2024-03-19 21:30Z',
#      'local': '2024-03-19 22:30+01:00'},
#     'terminal': '1',
#     'gate': 'A35',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5108',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'GCLP',
#      'iata': 'LPA',
#      'name': 'Gran Canaria Island'},
#     'scheduledTime': {'utc': '2024-03-19 16:20Z',
#      'local': '2024-03-19 16:20+00:00'},
#     'revisedTime': {'utc': '2024-03-19 16:20Z',
#      'local': '2024-03-19 16:20+00:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 21:30Z',
#      'local': '2024-03-19 22:30+01:00'},
#     'revisedTime': {'utc': '2024-03-19 21:30Z',
#      'local': '2024-03-19 22:30+01:00'},
#     'terminal': '1',
#     'gate': 'A20',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5112',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'scheduledTime': {'utc': '2024-03-19 20:25Z',
#      'local': '2024-03-19 21:25+01:00'},
#     'revisedTime': {'utc': '2024-03-19 20:25Z',
#      'local': '2024-03-19 21:25+01:00'},
#     'terminal': 'erminal2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 21:30Z',
#      'local': '2024-03-19 22:30+01:00'},
#     'revisedTime': {'utc': '2024-03-19 21:30Z',
#      'local': '2024-03-19 22:30+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5264',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LEMG', 'iata': 'AGP', 'name': 'Málaga'},
#     'scheduledTime': {'utc': '2024-03-19 18:00Z',
#      'local': '2024-03-19 19:00+01:00'},
#     'revisedTime': {'utc': '2024-03-19 18:00Z',
#      'local': '2024-03-19 19:00+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 21:30Z',
#      'local': '2024-03-19 22:30+01:00'},
#     'revisedTime': {'utc': '2024-03-19 21:30Z',
#      'local': '2024-03-19 22:30+01:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8537',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LEBL',
#      'iata': 'BCN',
#      'name': 'Barcelona'},
#     'scheduledTime': {'utc': '2024-03-19 18:40Z',
#      'local': '2024-03-19 19:40+01:00'},
#     'revisedTime': {'utc': '2024-03-19 18:40Z',
#      'local': '2024-03-19 19:40+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 21:30Z',
#      'local': '2024-03-19 22:30+01:00'},
#     'revisedTime': {'utc': '2024-03-19 21:30Z',
#      'local': '2024-03-19 22:30+01:00'},
#     'terminal': '1',
#     'gate': 'A35',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5108',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'GCLP',
#      'iata': 'LPA',
#      'name': 'Gran Canaria Island'},
#     'scheduledTime': {'utc': '2024-03-19 16:20Z',
#      'local': '2024-03-19 16:20+00:00'},
#     'revisedTime': {'utc': '2024-03-19 16:20Z',
#      'local': '2024-03-19 16:20+00:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 21:30Z',
#      'local': '2024-03-19 22:30+01:00'},
#     'revisedTime': {'utc': '2024-03-19 21:30Z',
#      'local': '2024-03-19 22:30+01:00'},
#     'terminal': '1',
#     'gate': 'A20',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5112',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'scheduledTime': {'utc': '2024-03-19 20:25Z',
#      'local': '2024-03-19 21:25+01:00'},
#     'revisedTime': {'utc': '2024-03-19 20:25Z',
#      'local': '2024-03-19 21:25+01:00'},
#     'terminal': 'erminal2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 21:30Z',
#      'local': '2024-03-19 22:30+01:00'},
#     'revisedTime': {'utc': '2024-03-19 21:30Z',
#      'local': '2024-03-19 22:30+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5264',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EGKK', 'iata': 'LGW', 'name': 'London'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 21:35Z',
#      'local': '2024-03-19 22:35+01:00'},
#     'revisedTime': {'utc': '2024-03-19 21:35Z',
#      'local': '2024-03-19 22:35+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 8631',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-19 20:25Z',
#      'local': '2024-03-19 21:25+01:00'},
#     'revisedTime': {'utc': '2024-03-19 20:25Z',
#      'local': '2024-03-19 21:25+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 21:35Z',
#      'local': '2024-03-19 22:35+01:00'},
#     'revisedTime': {'utc': '2024-03-19 21:35Z',
#      'local': '2024-03-19 22:35+01:00'},
#     'terminal': '1',
#     'gate': 'B02',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1958',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EGKK', 'iata': 'LGW', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-19 19:45Z',
#      'local': '2024-03-19 19:45+00:00'},
#     'terminal': 'N',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 21:35Z',
#      'local': '2024-03-19 22:35+01:00'},
#     'revisedTime': {'utc': '2024-03-19 21:35Z',
#      'local': '2024-03-19 22:35+01:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 8631',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'scheduledTime': {'utc': '2024-03-19 19:55Z',
#      'local': '2024-03-19 20:55+01:00'},
#     'terminal': '2F',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 21:40Z',
#      'local': '2024-03-19 22:40+01:00'},
#     'revisedTime': {'utc': '2024-03-19 21:40Z',
#      'local': '2024-03-19 22:40+01:00'},
#     'terminal': '1',
#     'gate': 'A22',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 1134',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A220-300'},
#    'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#   {'departure': {'airport': {'icao': 'LEMG', 'iata': 'AGP', 'name': 'Málaga'},
#     'scheduledTime': {'utc': '2024-03-19 18:00Z',
#      'local': '2024-03-19 19:00+01:00'},
#     'revisedTime': {'utc': '2024-03-19 18:00Z',
#      'local': '2024-03-19 19:00+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 21:40Z',
#      'local': '2024-03-19 22:40+01:00'},
#     'revisedTime': {'utc': '2024-03-19 21:40Z',
#      'local': '2024-03-19 22:40+01:00'},
#     'terminal': '1',
#     'gate': 'A37',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5106',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LSGG', 'iata': 'GVA', 'name': 'Geneva'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 21:40Z',
#      'local': '2024-03-19 22:40+01:00'},
#     'revisedTime': {'utc': '2024-03-19 21:40Z',
#      'local': '2024-03-19 22:40+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5186',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LEMG', 'iata': 'AGP', 'name': 'Málaga'},
#     'scheduledTime': {'utc': '2024-03-19 18:00Z',
#      'local': '2024-03-19 19:00+01:00'},
#     'revisedTime': {'utc': '2024-03-19 18:00Z',
#      'local': '2024-03-19 19:00+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 21:40Z',
#      'local': '2024-03-19 22:40+01:00'},
#     'revisedTime': {'utc': '2024-03-19 21:40Z',
#      'local': '2024-03-19 22:40+01:00'},
#     'terminal': '1',
#     'gate': 'A37',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5106',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LSGG', 'iata': 'GVA', 'name': 'Geneva'},
#     'scheduledTime': {'utc': '2024-03-19 19:55Z',
#      'local': '2024-03-19 20:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 21:40Z',
#      'local': '2024-03-19 22:40+01:00'},
#     'revisedTime': {'utc': '2024-03-19 21:40Z',
#      'local': '2024-03-19 22:40+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5186',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LIPH', 'iata': 'TSF', 'name': 'Treviso'},
#     'scheduledTime': {'utc': '2024-03-19 20:10Z',
#      'local': '2024-03-19 21:10+01:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 21:45Z',
#      'local': '2024-03-19 22:45+01:00'},
#     'revisedTime': {'utc': '2024-03-19 21:45Z',
#      'local': '2024-03-19 22:45+01:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 9165',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737 MAX 8 '},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EGSS', 'iata': 'STN', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-19 20:10Z',
#      'local': '2024-03-19 20:10+00:00'},
#     'revisedTime': {'utc': '2024-03-19 20:10Z',
#      'local': '2024-03-19 20:10+00:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 21:55Z',
#      'local': '2024-03-19 22:55+01:00'},
#     'revisedTime': {'utc': '2024-03-19 21:55Z',
#      'local': '2024-03-19 22:55+01:00'},
#     'terminal': '2',
#     'gate': 'Z43',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 176',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737 MAX 8 '},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LEMD', 'iata': 'MAD', 'name': 'Madrid'},
#     'scheduledTime': {'utc': '2024-03-19 19:00Z',
#      'local': '2024-03-19 20:00+01:00'},
#     'revisedTime': {'utc': '2024-03-19 19:00Z',
#      'local': '2024-03-19 20:00+01:00'},
#     'terminal': '4',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 22:05Z',
#      'local': '2024-03-19 23:05+01:00'},
#     'revisedTime': {'utc': '2024-03-19 22:05Z',
#      'local': '2024-03-19 23:05+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'I2 3674',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Iberia Express', 'iata': 'I2', 'icao': 'IBS'}},
#   {'departure': {'airport': {'icao': 'LEMD', 'iata': 'MAD', 'name': 'Madrid'},
#     'scheduledTime': {'utc': '2024-03-19 19:00Z',
#      'local': '2024-03-19 20:00+01:00'},
#     'revisedTime': {'utc': '2024-03-19 19:00Z',
#      'local': '2024-03-19 20:00+01:00'},
#     'terminal': '4',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-19 22:05Z',
#      'local': '2024-03-19 23:05+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'IB 3674',
#    'status': 'Expected',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Iberia', 'iata': 'IB', 'icao': 'IBE'}}]}

# %%
pd.json_normalize(flights_json["arrivals"])
# Out:
#       number    status codeshareStatus  isCargo departure.airport.icao  \
# 0    D8 3302  Expected      IsOperator    False                   EKCH
# 1     FI 528  Expected      IsOperator    False                   BIKF
# 2    LH 2206  Expected      IsOperator    False                   EDDM
# 3    EC 5064  Expected    IsCodeshared    False                   LIML
# 4    FR 2419  Expected      IsOperator    False                   GCTS
# ..       ...       ...             ...      ...                    ...
# 145  U2 5186  Expected      IsOperator    False                   LSGG
# 146  FR 9165  Expected      IsOperator    False                   LIPH
# 147   FR 176  Expected      IsOperator    False                   EGSS
# 148  I2 3674  Expected      IsOperator    False                   LEMD
# 149  IB 3674  Expected         Unknown    False                   LEMD
#
#     departure.airport.iata departure.airport.name departure.scheduledTime.utc  \
# 0                      CPH             Copenhagen           2024-03-19 10:00Z
# 1                      KEF              Reykjavik           2024-03-19 07:30Z
# 2                      MUC                 Munich           2024-03-19 09:50Z
# 3                      LIN                  Milan                         NaN
# 4                      TFS        Tenerife Island           2024-03-19 06:00Z
# ..                     ...                    ...                         ...
# 145                    GVA                 Geneva           2024-03-19 19:55Z
# 146                    TSF                Treviso           2024-03-19 20:10Z
# 147                    STN                 London           2024-03-19 20:10Z
# 148                    MAD                 Madrid           2024-03-19 19:00Z
# 149                    MAD                 Madrid           2024-03-19 19:00Z
#
#     departure.scheduledTime.local departure.revisedTime.utc  ...  \
# 0          2024-03-19 11:00+01:00         2024-03-19 10:00Z  ...
# 1          2024-03-19 07:30+00:00         2024-03-19 07:30Z  ...
# 2          2024-03-19 10:50+01:00         2024-03-19 09:50Z  ...
# 3                             NaN                       NaN  ...
# 4          2024-03-19 06:00+00:00         2024-03-19 06:00Z  ...
# ..                            ...                       ...  ...
# 145        2024-03-19 20:55+01:00                       NaN  ...
# 146        2024-03-19 21:10+01:00                       NaN  ...
# 147        2024-03-19 20:10+00:00         2024-03-19 20:10Z  ...
# 148        2024-03-19 20:00+01:00         2024-03-19 19:00Z  ...
# 149        2024-03-19 20:00+01:00         2024-03-19 19:00Z  ...
#
#     arrival.quality               aircraft.model          airline.name  \
# 0     [Basic, Live]            Boeing 737 MAX 8   Norwegian Air Sweden
# 1     [Basic, Live]            Boeing 737 MAX 8             Icelandair
# 2     [Basic, Live]  Airbus A320-200 (sharklets)             Lufthansa
# 3     [Basic, Live]                  Airbus A319        EasyJet Europe
# 4     [Basic, Live]    Boeing 737-800 (winglets)               Ryanair
# ..              ...                          ...                   ...
# 145   [Basic, Live]              Airbus A320-200               easyJet
# 146   [Basic, Live]            Boeing 737 MAX 8                Ryanair
# 147   [Basic, Live]            Boeing 737 MAX 8                Ryanair
# 148   [Basic, Live]                  Airbus A320        Iberia Express
# 149         [Basic]                  Airbus A320                Iberia
#
#     airline.iata airline.icao departure.checkInDesk departure.gate  \
# 0             D8          NSZ                   NaN            NaN
# 1             FI          ICE                   NaN            NaN
# 2             LH          DLH                   NaN            NaN
# 3             EC          EJU                   NaN            NaN
# 4             FR          RYR                   NaN            NaN
# ..           ...          ...                   ...            ...
# 145           U2          EZY                   NaN            NaN
# 146           FR          RYR                   NaN            NaN
# 147           FR          RYR                   NaN            NaN
# 148           I2          IBS                   NaN            NaN
# 149           IB          IBE                   NaN            NaN
#
#     aircraft.reg aircraft.modeS callSign
# 0            NaN            NaN      NaN
# 1            NaN            NaN      NaN
# 2            NaN            NaN      NaN
# 3            NaN            NaN      NaN
# 4            NaN            NaN      NaN
# ..           ...            ...      ...
# 145          NaN            NaN      NaN
# 146          NaN            NaN      NaN
# 147          NaN            NaN      NaN
# 148          NaN            NaN      NaN
# 149          NaN            NaN      NaN
#
# [150 rows x 30 columns]

# %%
def get_arrival_flights_info(list_icao):
    
    # Initializing the Dataframes
    arrivals_df=[]
    all_arrivals_df=[]

    # We need to have data about flights for the next day
    berlin_timezone = timezone('Europe/Berlin')
    today=datetime.now(berlin_timezone).date()
    tomorrow= (today + timedelta(1))
    # The AeroDataBox API only returns flight data for 12 hours. 
    # To get data for a whole day, we used two requests in a for loop. 
    times = [["00:00","11:59"],["12:00","23:59"]]

    for icao in list_icao: # For each airport ICAO in the list
      
      for time in times: # For each 12 hours in the day
        # The sections that form the URL were generated by the flights API
        url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{tomorrow}T{time[0]}/{tomorrow}T{time[1]}" # URL fo the flights API

        querystring = {"withLeg":"true",
          "direction":"Arrival", # We only need Arrival flights
          "withCancelled":"false",
          "withCodeshared":"true",
          "withCargo":"false",
          "withPrivate":"false"}
        
        headers = {
          "X-RapidAPI-Key": API_key_flights,
          "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
        }
        response = requests.get(url, headers=headers, params=querystring) # Send the request
        # In this function, we used json_normalize rather than using dictionaries as in the previous functions
        # JSON normalize JSON data into a Dataframe
        arrivals_df=pd.json_normalize(response.json()["arrivals"]) # Add information about arrivals to the arrivals_df
        # Add the arrival airport ICAO and the time when data were collected to our dataframe since this information is not included in the JSON response
        arrivals_df["arrival_airport_icao"]=icao
        arrivals_df["data_collected_time"]=datetime.now(berlin_timezone).strftime("%Y-%m-%d %H:%M:%S")
        
      
        # Concat all the generated Dataframe to our flights Dataframe
        all_arrivals_df.append(arrivals_df)
        all_flights_arrivals=pd.concat(all_arrivals_df, ignore_index=True)

        # Extract only the needed columns
        all_flights_arrivals = all_flights_arrivals.loc[:,["number","departure.airport.icao", "arrival.scheduledTime.local","arrival.terminal","arrival_airport_icao","data_collected_time"]]
        # Rename the columns
        all_flights_arrivals = all_flights_arrivals.rename(columns={"number": "flight_number", "departure.airport.icao": "departure_airport_icao", "arrival.scheduledTime.local": "scheduled_arrival_time","arrival.terminal":"arrival_terminal"})
        # Data cleaning for the scheduled_arrival_time
        all_flights_arrivals["scheduled_arrival_time"] = all_flights_arrivals["scheduled_arrival_time"].str[:-6]
        # Change the type of scheduled_arrival_time and data_collected_time
        all_flights_arrivals["scheduled_arrival_time"] = pd.to_datetime(all_flights_arrivals["scheduled_arrival_time"])
        all_flights_arrivals["data_collected_time"] = pd.to_datetime(all_flights_arrivals["data_collected_time"])
        
    return all_flights_arrivals

# %%
all_flights_arrivals_df=get_arrival_flights_info(airport_infos_df["airport_icao"])

# %%
all_flights_arrivals_df
# Out:
#     flight_number departure_airport_icao scheduled_arrival_time  \
# 0           QR 79                   OTHH    2024-03-19 06:50:00
# 1         FR 2600                   EVRA    2024-03-19 07:35:00
# 2         DS 1185                   LFSB    2024-03-19 07:45:00
# 3         U2 1185                   LFSB    2024-03-19 07:45:00
# 4         W6 2315                   LHBP    2024-03-19 07:45:00
# ..            ...                    ...                    ...
# 807       EW 2465                   EGLL    2024-03-19 21:10:00
# 808       EW 2785                   LHBP    2024-03-19 21:35:00
# 809       KL 1879                   EHAM    2024-03-19 22:30:00
# 810        LH 136                   EDDF    2024-03-19 22:40:00
# 811       LH 2152                   EDDM    2024-03-19 22:35:00
#
#     arrival_terminal arrival_airport_icao data_collected_time
# 0                  1                 EDDB 2024-03-18 16:05:32
# 1                  2                 EDDB 2024-03-18 16:05:32
# 2                  1                 EDDB 2024-03-18 16:05:32
# 3                  1                 EDDB 2024-03-18 16:05:32
# 4                  2                 EDDB 2024-03-18 16:05:32
# ..               ...                  ...                 ...
# 807                1                 EDDS 2024-03-18 16:05:34
# 808                1                 EDDS 2024-03-18 16:05:34
# 809                3                 EDDS 2024-03-18 16:05:34
# 810                1                 EDDS 2024-03-18 16:05:34
# 811                1                 EDDS 2024-03-18 16:05:34
#
# [812 rows x 6 columns]

# %%
all_flights_arrivals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 812 entries, 0 to 811
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   flight_number           812 non-null    object
#  1   departure_airport_icao  808 non-null    object
#  2   scheduled_arrival_time  812 non-null    datetime64[ns]
#  3   arrival_terminal        809 non-null    object
#  4   arrival_airport_icao    812 non-null    object
#  5   data_collected_time     812 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), object(4)
# memory usage: 38.2+ KB

# %%
all_flights_arrivals_df.to_sql('flights',
                if_exists='append',
                con=connection_string,
                index=False)
# Out:
# 812

# %%
flight_infos_from_sql = pd.read_sql("flights", con=connection_string)
print(flight_infos_from_sql)
# Out:
#      flight_id flight_number departure_airport_icao scheduled_arrival_time  \
# 0            1         QR 79                   OTHH    2024-03-19 06:50:00
# 1            2       FR 2600                   EVRA    2024-03-19 07:35:00
# 2            3       DS 1185                   LFSB    2024-03-19 07:45:00
# 3            4       U2 1185                   LFSB    2024-03-19 07:45:00
# 4            5       W6 2315                   LHBP    2024-03-19 07:45:00
# ..         ...           ...                    ...                    ...
# 807        808       EW 2465                   EGLL    2024-03-19 21:10:00
# 808        809       EW 2785                   LHBP    2024-03-19 21:35:00
# 809        810       KL 1879                   EHAM    2024-03-19 22:30:00
# 810        811        LH 136                   EDDF    2024-03-19 22:40:00
# 811        812       LH 2152                   EDDM    2024-03-19 22:35:00
#
#     arrival_terminal arrival_airport_icao data_collected_time
# 0                  1                 EDDB 2024-03-18 16:05:32
# 1                  2                 EDDB 2024-03-18 16:05:32
# 2                  1                 EDDB 2024-03-18 16:05:32
# 3                  1                 EDDB 2024-03-18 16:05:32
# 4                  2                 EDDB 2024-03-18 16:05:32
# ..               ...                  ...                 ...
# 807                1                 EDDS 2024-03-18 16:05:34
# 808                1                 EDDS 2024-03-18 16:05:34
# 809                3                 EDDS 2024-03-18 16:05:34
# 810                1                 EDDS 2024-03-18 16:05:34
# 811                1                 EDDS 2024-03-18 16:05:34
#
# [812 rows x 7 columns]
